# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten

# %%
df = pd.read_csv('data_test.csv')

# %%
df
# Out:
#      hand_score  position  3bet  4bet  street  preflop_aggressor  betO:pot   \
# 0          0.25         0     0     0       0                  0        0.5
# 1          0.15         1     0     0       0                  0        0.0
# 2          0.65         0     0     0       1                  0        0.0
# 3          0.67         1     0     0       1                  0        0.5
# 4          0.67         1     0     0       1                  0        0.0
# ..          ...       ...   ...   ...     ...                ...        ...
# 265        0.30         1     0     0       2                  0        0.0
# 266        0.99         1     0     0       3                  0        0.0
# 267        0.00         0     0     0       0                  0        0.5
# 268        0.60         0     0     0       0                  0        0.5
# 269        0.35         0     0     0       0                  0        0.5
#
#      betO:stack  betO_in_BB  output
# ...

# %%
df["hand_score"] = df.hand_score.astype(float)
X = np.array(df.drop(['output'], 1))
y = np.array(df['output'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train = np.asarray(X_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %%
model = Sequential()
model.add(Dense(64, input_dim=9, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss = "binary_crossentropy",
             optimizer = "adam",
             metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, batch_size = 16, epochs = 15, validation_split = 0.3)
# Out:
# Epoch 1/15
# 10/10 [==============================] - 2s 120ms/step - loss: 0.4322 - accuracy: 0.1878 - val_loss: 0.0420 - val_accuracy: 0.3385
# Epoch 2/15
# 10/10 [==============================] - 0s 6ms/step - loss: -0.1760 - accuracy: 0.2614 - val_loss: -0.3877 - val_accuracy: 0.3385
# Epoch 3/15
# 10/10 [==============================] - 0s 6ms/step - loss: -0.6768 - accuracy: 0.2699 - val_loss: -0.8321 - val_accuracy: 0.3385
# Epoch 4/15
# 10/10 [==============================] - 0s 10ms/step - loss: -0.8361 - accuracy: 0.2889 - val_loss: -1.2692 - val_accuracy: 0.3385
# Epoch 5/15
# 10/10 [==============================] - 0s 7ms/step - loss: -0.7221 - accuracy: 0.2997 - val_loss: -1.7728 - val_accuracy: 0.3385
# Epoch 6/15
# 10/10 [==============================] - 0s 7ms/step - loss: -1.4003 - accuracy: 0.2876 - val_loss: -2.4513 - val_accuracy: 0.3385
# Epoch 7/15
# ...

# %%
import tensorflowjs as tfjs

# %%
tfjs.converters.save_keras_model(model, '/Users/bryan/Documents/HUPoker')
# Out:
# /anaconda3/envs/compsci371d/lib/python3.8/site-packages/tensorflowjs/converters/keras_h5_conversion.py:123: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   return h5py.File(h5file)

# %%
model.save('my_model.h5')
